# %% [markdown]
# # Test a counting function

# %%
from pathlib import Path
import random as rd
import numpy as np

# %%
from data import get_data_paths, read_tif_image
from display import imshow, test_method
from processing import local_maximums_of_ndvi_connexe_components

# %% [markdown]
# ## Images extraction

# %%
images_to_test = [
    "/Users/Theo/Documents/Dépots Githubs/2023/inf573vegetalisation/flair/dataflair/flair_1_toy_aerial_train/D030_2021/Z8_UN/img/IMG_019824.tif",
    "/Users/Theo/Documents/Dépots Githubs/2023/inf573vegetalisation/flair/dataflair/flair_1_toy_aerial_train/D070_2020/Z11_UA/img/IMG_047762.tif",
    "/Users/Theo/Documents/Dépots Githubs/2023/inf573vegetalisation/flair/dataflair/flair_1_toy_aerial_train/D031_2019/Z11_UN/img/IMG_020838.tif",
    "/Users/Theo/Documents/Dépots Githubs/2023/inf573vegetalisation/flair/dataflair/flair_1_toy_aerial_train/D074_2020/Z10_NF/img/IMG_051322.tif",
    "/Users/Theo/Documents/Dépots Githubs/2023/inf573vegetalisation/flair/dataflair/flair_1_toy_aerial_train/D032_2019/Z3_AA/img/IMG_022673.tif",
    "../flair/dataflair/flair_1_toy_aerial_train/D031_2019/Z8_UU/img/IMG_020484.tif"
]

# %%
test_method(local_maximums_of_ndvi_connexe_components, images_to_test)
